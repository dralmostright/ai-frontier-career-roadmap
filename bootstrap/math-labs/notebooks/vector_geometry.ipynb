# %%
print('Hello World')
# Out:
# Hello World

# %%
import 'bootstrap/math-labs/src/linear_algebra.py'
# Out:
#   Cell In[2], line 1
#     import 'bootstrap/math-labs/src/linear_algebra.py'
#            ^
# SyntaxError: invalid syntax
